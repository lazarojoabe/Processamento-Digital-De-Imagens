# %%
# code here
import cv2
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1)	Abrir as imagens coloridas e mostrar a imagem e seus histogramas (separados) cada canal de cor. Considerar os seguintes sistemas de cores:
# a.	RGB
# b.	HSV ou HSI
# c.	Lab

# %%
def calcHist(img):
    canal1 = np.zeros(256)
    canal2 = np.zeros(256)
    canal3 = np.zeros(256)

    # Obter as dimensões da imagem
    altura, largura, _ = img.shape
    for i in range(altura):
        for j in range(largura):
            pixel_value = img[i, j]
            canal1[pixel_value[0]] += 1
            canal2[pixel_value[1]] += 1
            canal3[pixel_value[2]] += 1
    return canal1, canal2, canal3

img1 = cv2.imread("image.jpg", cv2.IMREAD_COLOR)
img1RGB = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

img2 = cv2.imread("image2.jpg", cv2.IMREAD_COLOR)
img2RGB = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

img3 = cv2.imread("Lenna.jpg", cv2.IMREAD_COLOR)
img3RGB = cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)

img1HSV = cv2.cvtColor(img1, cv2.COLOR_BGR2HSV)
img2HSV = cv2.cvtColor(img2, cv2.COLOR_BGR2HSV)
img3HSV = cv2.cvtColor(img3, cv2.COLOR_BGR2HSV)

hist1 = calcHist(img1RGB)
hist2 = calcHist(img2RGB)
hist3 = calcHist(img3RGB)

fig = plt.figure( figsize=(24, 8))

plt.subplot(2, 3, 1).set_title("Imagem 1")
plt.bar(range(256), hist1[0], alpha=0.75, color='r', label='Histograma-Vermelho')
plt.axis( [0, 255, 0, 12000] )


plt.bar(range(256), hist1[1], alpha=0.75, color='g', label='Histograma-Verde')
plt.axis( [0, 255, 0, 12000] )

plt.bar(range(256), hist1[2], alpha=0.75, color='b', label='Histograma-Azul');
plt.axis( [0, 255, 0, 12000] )

plt.subplot(2, 3, 2).set_title("Imagem 2")

plt.bar(range(256), hist2[0], alpha=0.75, color='r', label='Histograma-Vermelho')
plt.axis( [0, 255, 0, 17000] )

plt.bar(range(256), hist2[1], alpha=0.75, color='g', label='Histograma-Verde')
plt.axis( [0, 255, 0, 17000] )

plt.bar(range(256), hist2[2], alpha=0.75, color='b', label='Histograma-Azul');
plt.axis( [0, 255, 0, 17000] )

plt.subplot(2, 3, 3).set_title("Imagem 3")

plt.bar(range(256), hist3[0], alpha=0.75, color='r', label='Histograma-Vermelho')
plt.axis( [0, 255, 0, 10000] )

plt.bar(range(256), hist3[1], alpha=0.75, color='g', label='Histograma-Verde')
plt.axis( [0, 255, 0, 10000] )

plt.bar(range(256), hist3[2], alpha=0.75, color='b', label='Histograma-Azul');
plt.axis( [0, 255, 0, 10000] )

plt.subplot(2, 3, 4)
plt.imshow(img1RGB)

plt.subplot(2, 3, 5)
plt.imshow(img2RGB)

plt.subplot(2, 3, 6)
plt.imshow(img3RGB)

plt.show()

# %%
#HISTOGRAMAS DAS IMAGENS EM  HSV

histHSV1 = calcHist(img1HSV)
histHSV2 = calcHist(img2HSV)
histHSV3 = calcHist(img3HSV)

fig = plt.figure(figsize=(24, 8))

plt.subplot(1, 3, 1).set_title("Histograma imagem HSV 1: ")
plt.bar(range(256), histHSV1[0], alpha=0.75, color='y', label='Histograma-Vermelho')
plt.axis( [0, 255, 0, 20000] )

plt.bar(range(256), histHSV1[1], alpha=0.75, color='r', label='Histograma-Vermelho')
plt.axis( [0, 255, 0, 20000] )


plt.bar(range(256), histHSV1[2], alpha=0.75, color='m', label='Histograma-Vermelho')
plt.axis( [0, 255, 0, 20000] )

plt.subplot(1, 3, 2).set_title("Histograma imagem HSV 2: ")
plt.bar(range(256), histHSV2[0], alpha=0.75, color='y', label='Histograma-Vermelho')
plt.axis( [0, 255, 0, 20000] )

plt.bar(range(256), histHSV2[1], alpha=0.75, color='r', label='Histograma-Vermelho')
plt.axis( [0, 255, 0, 20000] )

plt.bar(range(256), histHSV2[2], alpha=0.75, color='m', label='Histograma-Vermelho')
plt.axis( [0, 255, 0, 20000] )

plt.subplot(1, 3, 3).set_title("Histograma imagem HSV 3: ")
plt.bar(range(256), histHSV3[0], alpha=0.75, color='y', label='Histograma-Vermelho')
plt.axis( [0, 255, 0, 20000] )

plt.bar(range(256), histHSV3[1], alpha=0.75, color='r', label='Histograma-Vermelho')
plt.axis( [0, 255, 0, 20000] )

plt.bar(range(256), histHSV3[2], alpha=0.75, color='m')
plt.axis( [0, 255, 0, 20000] )

plt.legend(("Matiz", "Saturação", "Intensidade"));

# %%
img1LAB = cv2.cvtColor(img1RGB, cv2.COLOR_RGB2LAB)
img2LAB = cv2.cvtColor(img2RGB, cv2.COLOR_RGB2LAB)
img3LAB = cv2.cvtColor(img3RGB, cv2.COLOR_RGB2LAB)

hist1LAB = calcHist(img1LAB)
hist2LAB = calcHist(img2LAB)
hist3LAB = calcHist(img3LAB)

fig = plt.figure(figsize=(24, 8))

plt.subplot(1, 3, 1).set_title("Histograma imagem LAB 1: ")
plt.bar(range(256), hist1LAB[0], alpha=0.75, color='y', label='Histograma-Vermelho')
plt.axis( [0, 255, 0, 20000] )

plt.bar(range(256), hist1LAB[1], alpha=0.75, color='g', label='Histograma-Vermelho')
plt.axis( [0, 255, 0, 20000] )


plt.bar(range(256), hist1LAB[2], alpha=0.75, color='m', label='Histograma-Vermelho')
plt.axis( [0, 255, 0, 20000] )

plt.subplot(1, 3, 2).set_title("Histograma imagem LAB 2: ")
plt.bar(range(256), hist2LAB[0], alpha=0.75, color='y', label='Histograma-Vermelho')
plt.axis( [0, 255, 0, 20000] )

plt.bar(range(256), hist2LAB[1], alpha=0.75, color='g', label='Histograma-Vermelho')
plt.axis( [0, 255, 0, 20000] )

plt.bar(range(256), hist2LAB[2], alpha=0.75, color='m', label='Histograma-Vermelho')
plt.axis( [0, 255, 0, 20000] )

plt.subplot(1, 3, 3).set_title("Histograma imagem LAB 3: ")
plt.bar(range(256), hist3LAB[0], alpha=0.75, color='y', label='Histograma-Vermelho')
plt.axis( [0, 255, 0, 20000] )

plt.bar(range(256), hist3LAB[1], alpha=0.75, color='g', label='Histograma-Vermelho')
plt.axis( [0, 255, 0, 20000] )

plt.bar(range(256), hist3LAB[2], alpha=0.75, color='m', label='Histograma-Vermelho')
plt.axis( [0, 255, 0, 20000] )

plt.legend(("Luminosidade", "Coordenada vermelho/verde", "Coordenada amarelo/azul"));

# %%
def calcVarB_e_VarG(k, histograma):
    P1 = np.sum(histograma[:k])
    P2 = 1 - P1

    m1 = np.sum(np.arange(k) * histograma[:k]) / (P1 + 1e-10)  # Evitar divisão por zero
    m2 = np.sum(np.arange(k, 256) * histograma[k:]) / (P2 + 1e-10)  # Evitar divisão por zero
    
    mG = P1 * m1 + P2 * m2
    varB = P1 * P2 * (m1 - m2)**2

    varG = np.sum(histograma * (np.arange(256) - mG)**2)

    return varB, varG

def eta(k, histograma):
    result = calcVarB_e_VarG(k, histograma)
    varB = result[0]
    varG = result[1]
    return varB / (varG + 1e-10)  # Evitar divisão por zero

def acharMelhorKEMaiorEta(histograma):
    maiorEta = 0
    melhorK = 0
    for i in range(0, 256):
        valor = eta(i, histograma)
        if maiorEta < valor:
            melhorK = i
            maiorEta = valor
    return melhorK, maiorEta

# %% [markdown]
# 2)	Utilizando a imagem do mandrill, faça rotinas para detecção do focinho (região vermelha e azul). Utilize algum algoritmo de limiarização.

# %%
img_mand = cv2.imread("mandrill.tiff", cv2.IMREAD_COLOR)

# Convertendo a imagem para o espaço de cor HSV (Hue, Saturation, Value)
hsv_img = cv2.cvtColor(img_mand, cv2.COLOR_BGR2HSV)

lower_blue = np.array([80, 80, 80], dtype=np.uint8)
upper_blue = np.array([140, 255, 255], dtype=np.uint8)

# Criando uma máscara para os tons de azul
blue_mask = cv2.inRange(hsv_img, lower_blue, upper_blue)

# Encontrando contornos na imagem segmentada
contours, _ = cv2.findContours(blue_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Desenhando os contornos na imagem original
img_contours = img_mand.copy()
cv2.drawContours(img_contours, contours, -1, (0, 255, 0), 2)

# Contando os núcleos celulares
num_nucleos = len(contours)

# Mostrando as imagens resultantes
titles = ['Original Image', 'Blue Nuclei Segmentation', 'Contours']
images = [cv2.cvtColor(img_mand, cv2.COLOR_BGR2RGB), blue_mask, cv2.cvtColor(img_contours, cv2.COLOR_BGR2RGB)]

img_contours_rgb = cv2.cvtColor(img_contours, cv2.COLOR_BGR2RGB)
img = cv2.cvtColor(img_mand, cv2.COLOR_BGR2RGB)
fig = plt.figure(figsize=(24, 8))

plt.subplot(1, 2, 1).set_title("Imagem Original:")
plt.imshow(img)
plt.axis('off')

plt.subplot(1, 2, 2).set_title("Imagem com núcleos azuis detectados:")
plt.imshow(img_contours_rgb)
plt.axis('off')

plt.show()

print(f'Número de núcleos azuis na imagem: {num_nucleos}')
# Converter img_contours para RGB antes de salvar
img_he_contours_rgb_for_saving = cv2.cvtColor(img_contours_rgb, cv2.COLOR_BGR2RGB)

output_path = 'imagem_he_com_contornos.jpg'
cv2.imwrite(output_path, img_he_contours_rgb_for_saving)
# Out:
# Número de núcleos azuis na imagem: 2432
# True

# %% [markdown]
# 3)	Utilizando a imagem HE.jpg, tente detectar e contar a quantidade de núcleos celulares (em azul). Aplicar o Ostu para os 9 canais de cores e avaliar qual foi melhor (R,G,B,H,S,V,L,a,b)

# %%
#CONTAGEM DE NÚCLEOS CELULARES
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('HE.jpg')

# Convertendo a imagem para o espaço de cor HSV (Hue, Saturation, Value)
hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

lower_blue = np.array([100, 100, 100], dtype=np.uint8)
upper_blue = np.array([140, 255, 255], dtype=np.uint8)

# Criando uma máscara para os tons de azul
blue_mask = cv2.inRange(hsv_img, lower_blue, upper_blue)

# Encontrando contornos na imagem segmentada
contours, _ = cv2.findContours(blue_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Desenhando os contornos na imagem original
img_contours = img.copy()
cv2.drawContours(img_contours, contours, -1, (0, 255, 0), 2)

# Contando os núcleos celulares
num_nucleos = len(contours)

# Mostrando as imagens resultantes
titles = ['Original Image', 'Blue Nuclei Segmentation', 'Contours']
images = [cv2.cvtColor(img, cv2.COLOR_BGR2RGB), blue_mask, cv2.cvtColor(img_contours, cv2.COLOR_BGR2RGB)]

img_contours_rgb = cv2.cvtColor(img_contours, cv2.COLOR_BGR2RGB)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
fig = plt.figure(figsize=(24, 8))

plt.subplot(1, 2, 1).set_title("Imagem Original:")
plt.imshow(img)
plt.axis('off')

plt.subplot(1, 2, 2).set_title("Imagem com núcleos azuis detectados:")
plt.imshow(img_contours_rgb)
plt.axis('off')

plt.show()

print(f'Número de núcleos azuis na imagem: {num_nucleos}')
# Converter img_contours para RGB antes de salvar
img_contours_rgb_for_saving = cv2.cvtColor(img_contours_rgb, cv2.COLOR_BGR2RGB)

output_path = 'imagem_com_contornos.jpg'
cv2.imwrite(output_path, img_contours_rgb_for_saving)
# Out:
# Número de núcleos azuis na imagem: 373
# True

# %%
#AVALIAÇÃO DE OTSU

def normalizaHist(histograma):
    return histograma/sum(histograma)

#está sendo considerado o melhor otsu aquele histograma que tiver um maior valor de Eta
def avaliaOtsu(histograma):
    maior = indiceDoMaior = 0
    for i in range(len(histograma)):
        _, valor = acharMelhorKEMaiorEta(histograma[i])
        if valor > maior:
            maior = valor
            indiceDoMaior = i
    return indiceDoMaior

imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
imgHSV = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
imgLab = cv2.cvtColor(imgRGB, cv2.COLOR_RGB2LAB)

histRGB = calcHist(imgRGB)
histHSV = calcHist(imgHSV)
histLab = calcHist(imgLab)

histogs = [histRGB[0], histRGB[1], histRGB[2], histHSV[0], histHSV[1], histHSV[2], histLab[0], histLab[1], histLab[2]]

histogsNormalizados = normalizaHist(histogs)

melhor_canal = avaliaOtsu(histogsNormalizados)

match melhor_canal:
    case 0:
        print("O melhor canal é o R")
    case 1:
        print("O melhor canal é o G")
    case 2:
        print("O melhor canal é o B")
    case 3:
        print("O melhor canal é o H")
    case 4:
        print("O melhor canal é o S")
    case 5:
        print("O melhor canal é o V")
    case 6:
        print("O melhor canal é o L")
    case 7:
        print("O melhor canal é o A")
    case 8:
        print("O melhor canal é o B")
    
print("Segue o histograma do melhor Otsu:")
plt.bar(range(256), histogs[melhor_canal], alpha=0.75, color='m')
plt.axis( [0, 255, 0, 9000] );
# Out:
# O melhor canal é o V
# Segue o histograma do melhor Otsu:
